# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
interestRate_data = pd.read_csv('InterestRate.csv')

# Extract date part and convert using format for abbreviated month
date_str = interestRate_data['Release Date'].str.extract(r'([A-Za-z]{3} \d{1,2}, \d{4})')[0]
interestRate_data['Parsed Date'] = pd.to_datetime(date_str, format='%b %d, %Y')

# Sort by parsed date
interestRate_data = interestRate_data.sort_values('Parsed Date')

# Create Year-Month column for x-axis
interestRate_data['YearMonth'] = interestRate_data['Parsed Date'].dt.strftime('%Y-%m')

plt.figure(figsize=(14, 5))

plt.plot(interestRate_data['YearMonth'], interestRate_data['Actual'], label='Actual', marker='o')
plt.plot(interestRate_data['YearMonth'], interestRate_data['Forecast'], label='Forecast', marker='x')

plt.title('Interest Rate: Actual vs Forecast Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Interest Rate Values')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.xticks(rotation=90, ha='right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
interestRate_data = pd.read_csv('InterestRate.csv')

# Extract date part and convert to datetime
date_str = interestRate_data['Release Date'].str.extract(r'([A-Za-z]{3} \d{1,2}, \d{4})')[0]
interestRate_data['Parsed Date'] = pd.to_datetime(date_str, format='%b %d, %Y')

# Extract month and year
interestRate_data['Month'] = interestRate_data['Parsed Date'].dt.month
interestRate_data['Year'] = interestRate_data['Parsed Date'].dt.year

# Create a string like "2018 Jan"
interestRate_data['YearMonthStr'] = interestRate_data['Year'].astype(str) + ' ' + interestRate_data['Parsed Date'].dt.strftime('%b')

# Sort data by Month first, then Year
interestRate_data = interestRate_data.sort_values(by=['Month', 'Year'])

# Plot
plt.figure(figsize=(16, 6))

plt.plot(interestRate_data['YearMonthStr'], interestRate_data['Actual'], marker='o', label='Actual')
plt.plot(interestRate_data['YearMonthStr'], interestRate_data['Forecast'], marker='x', label='Forecast')

plt.title('Interest Rate: Actual vs Forecast (Grouped by Month, then Year)')
plt.xlabel('Year Month')
plt.ylabel('Interest Rate Values')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# Actual vs Forecast values

import pandas as pd
import matplotlib.pyplot as plt

# Load your existing CSV file
interestRate_data = pd.read_csv('CPI.csv')

# Drop rows where Actual is missing (NaN)
interestRate_data = interestRate_data.dropna(subset=['Actual'])

# Plot Actual (x-axis) vs Forecast (y-axis)
plt.scatter(interestRate_data['Actual'], interestRate_data['Forecast'])
plt.xlabel('Actual Values')
plt.ylabel('Forecast Values')
plt.title('Forecast vs Actual Values')
plt.grid(True)
plt.show()

# %%
# Previous vs Actual values

import pandas as pd
import matplotlib.pyplot as plt

# Load your existing CSV file
interestRate_data = pd.read_csv('CPI.csv')

# Drop rows where Actual is missing (NaN)
interestRate_data = interestRate_data.dropna(subset=['Actual'])

# Plot Actual (x-axis) vs Previous (y-axis)
plt.scatter(interestRate_data['Actual'], interestRate_data['Previous'])
plt.xlabel('Actual Values')
plt.ylabel('Previoius Values')
plt.title('Previous vs Actual Values')
plt.grid(True)
plt.show()
