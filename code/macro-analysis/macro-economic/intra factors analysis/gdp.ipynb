# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
gdp_data = pd.read_csv('GDP.csv')

# Extract date part and convert using format for abbreviated month
date_str = gdp_data['Release Date'].str.extract(r'([A-Za-z]{3} \d{1,2}, \d{4})')[0]
gdp_data['Parsed Date'] = pd.to_datetime(date_str, format='%b %d, %Y')

# Sort by parsed date
gdp_data = gdp_data.sort_values('Parsed Date')

# Create Year-Month column for x-axis
gdp_data['YearMonth'] = gdp_data['Parsed Date'].dt.strftime('%Y-%m')

plt.figure(figsize=(14, 5))

plt.plot(gdp_data['YearMonth'], gdp_data['Actual'], label='Actual', marker='o')
plt.plot(gdp_data['YearMonth'], gdp_data['Forecast'], label='Forecast', marker='x')

plt.title('GDP: Actual vs Forecast Over Time')
plt.xlabel('Year-Month')
plt.ylabel('GDP Values')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.xticks(rotation=90, ha='right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
gdp_data = pd.read_csv('GDP.csv')

# Extract date part and convert to datetime
date_str = gdp_data['Release Date'].str.extract(r'([A-Za-z]{3} \d{1,2}, \d{4})')[0]
gdp_data['Parsed Date'] = pd.to_datetime(date_str, format='%b %d, %Y')

# Extract month and year
gdp_data['Month'] = gdp_data['Parsed Date'].dt.month
gdp_data['Year'] = gdp_data['Parsed Date'].dt.year

# Create a string like "2018 Jan"
gdp_data['YearMonthStr'] = gdp_data['Year'].astype(str) + ' ' + gdp_data['Parsed Date'].dt.strftime('%b')

# Sort data by Month first, then Year
gdp_data = gdp_data.sort_values(by=['Month', 'Year'])

# Plot
plt.figure(figsize=(16, 6))

plt.plot(gdp_data['YearMonthStr'], gdp_data['Actual'], marker='o', label='Actual')
plt.plot(gdp_data['YearMonthStr'], gdp_data['Forecast'], marker='x', label='Forecast')

plt.title('GDP: Actual vs Forecast (Grouped by Month, then Year)')
plt.xlabel('Year Month')
plt.ylabel('GDP Values')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# Actual vs Forecast values

import pandas as pd
import matplotlib.pyplot as plt

# Load your existing CSV file
gdp_data = pd.read_csv('GDP.csv')

# Drop rows where Actual is missing (NaN)
gdp_data = gdp_data.dropna(subset=['Actual'])

# Plot Actual (x-axis) vs Forecast (y-axis)
plt.scatter(gdp_data['Actual'], gdp_data['Forecast'])
plt.xlabel('Actual Values')
plt.ylabel('Forecast Values')
plt.title('Forecast vs Actual Values')
plt.grid(True)
plt.show()

# %%
# Previous vs Actual values

import pandas as pd
import matplotlib.pyplot as plt

# Load your existing CSV file
gdp_data = pd.read_csv('CPI.csv')

# Drop rows where Actual is missing (NaN)
gdp_data = gdp_data.dropna(subset=['Actual'])

# Plot Actual (x-axis) vs Previous (y-axis)
plt.scatter(gdp_data['Actual'], gdp_data['Previous'])
plt.xlabel('Actual Values')
plt.ylabel('Previoius Values')
plt.title('Previous vs Actual Values')
plt.grid(True)
plt.show()
